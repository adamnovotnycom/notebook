# %% [markdown]
# ## yfinance + Google Colab + VS Code playground
#
# [Google Colab + VS Code](https://developers.googleblog.com/en/google-colab-is-coming-to-vs-code)
#
# [yfinance github](https://github.com/ranaroussi/yfinance)

# %%
# !pip freeze | grep pandas
# Out:
# geopandas==1.1.1
# pandas==2.2.2
# pandas-datareader==0.10.0
# pandas-gbq==0.30.0
# pandas-stubs==2.2.2.240909
# sklearn-pandas==2.2.0

# %%
# %pip install yfinance==0.2.66

# %%
import os
import yfinance as yf
from pathlib import Path

# %%
# Stock example
# symbol = "SPY"
symbol = "CL=F"
symbol_yf = yf.Ticker(symbol)
print(symbol_yf.info)
price_df = symbol_yf.history(period="max")
price_df = price_df.round(6)
price_df.tail(10)
# Out:
# {'maxAge': 86400, 'priceHint': 2, 'previousClose': 59.14, 'open': 58.8, 'dayLow': 57.38, 'dayHigh': 58.8, 'regularMarketPreviousClose': 59.14, 'regularMarketOpen': 58.8, 'regularMarketDayLow': 57.38, 'regularMarketDayHigh': 58.8, 'volume': 324244, 'regularMarketVolume': 324244, 'averageVolume': 249320, 'averageVolume10days': 242143, 'averageDailyVolume10Day': 242143, 'bid': 57.96, 'ask': 58.0, 'expireDate': 1763596800, 'openInterest': 379528, 'fiftyTwoWeekLow': 55.12, 'fiftyTwoWeekHigh': 80.77, 'allTimeHigh': 147.27, 'allTimeLow': -40.32, 'fiftyDayAverage': 60.868, 'twoHundredDayAverage': 64.3541, 'currency': 'USD', 'tradeable': False, 'quoteType': 'FUTURE', 'symbol': 'CL=F', 'language': 'en-US', 'region': 'US', 'typeDisp': 'Futures', 'quoteSourceName': 'Delayed Quote', 'triggerable': False, 'customPriceAlertConfidence': 'NONE', 'contractSymbol': False, 'headSymbolAsString': 'CL=F', 'corporateActions': [], 'regularMarketTime': 1763666989, 'underlyingSymbol': 'CLF26.NYM', 'underlyingE
# ...
